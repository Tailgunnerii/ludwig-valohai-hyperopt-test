# %% [markdown]
# # Hyperparameter Optimization with Hyperopt

# %% [markdown]
# ## Install Hyperopt package

# %%
# !pip install hyperopt
# !pip install ludwig
# !pip install ludwig[viz]
# Out:
# Collecting hyperopt
#   Downloading https://files.pythonhosted.org/packages/7e/11/8bbbb5edb78c40a2bd0f6b730e3dc0f29ffbaea9a59520eb9622951e9151/hyperopt-0.2.3-py3-none-any.whl (1.9MB)
#      |████████████████████████████████| 1.9MB 23.6MB/s
# Collecting scipy
#   Downloading https://files.pythonhosted.org/packages/dd/82/c1fe128f3526b128cfd185580ba40d01371c5d299fcf7f77968e22dfcc2e/scipy-1.4.1-cp37-cp37m-manylinux1_x86_64.whl (26.1MB)
#      |████████████████████████████████| 26.1MB 53.5MB/s
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.7/site-packages (from hyperopt) (4.40.0)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.7/site-packages (from hyperopt) (1.18.1)
# Collecting networkx==2.2
#   Downloading https://files.pythonhosted.org/packages/f3/f4/7e20ef40b118478191cec0b58c3192f822cace858c19505c7670961b76b2/networkx-2.2.zip (1.7MB)
#      |████████████████████████████████| 1.7MB 52.6MB/s
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from hyperopt) (1.13.0)
# Requirement already satisfied: future in /opt/conda/lib/python3.7/site-packages (from hyperopt) (0.18.2)
# Collecting cloudpickle
#   Downloading https://files.pythonhosted.org/packages/c1/49/334e279caa3231255725c8e860fa93e72083567625573421db8875846c14/cloudpickle-1.2.2-py2.py3-none-any.whl
# Requirement already satisfied: decorator>=4.3.0 in /opt/conda/lib/python3.7/site-packages (from networkx==2.2->hyperopt) (4.4.1)
# Building wheels for collected packages: networkx
# done
#   Created wheel for networkx: filename=networkx-2.2-py2.py3-none-any.whl size=1527322 sha256=ea2ddc9938830a640149a2da2fd26223ccc2e4abc908a0eb01ea892922c53fb6
#   Stored in directory: /home/jovyan/.cache/pip/wheels/68/f8/29/b53346a112a07d30a5a84d53f19aeadaa1a474897c0423af91
# Successfully built networkx
# Installing collected packages: scipy, networkx, cloudpickle, hyperopt
# Successfully installed cloudpickle-1.2.2 hyperopt-0.2.3 networkx-2.2 scipy-1.4.1
# Collecting ludwig
#   Downloading https://files.pythonhosted.org/packages/9c/59/59a658a5846cda34fc3832992e28e65d727c54a576ff48bcb3c90c3072e8/ludwig-0.2.1.tar.gz (164kB)
#      |████████████████████████████████| 174kB 21.8MB/s
# Collecting Cython>=0.25
#   Downloading https://files.pythonhosted.org/packages/d8/58/2deb24de3c10cc4c0f09639b46f4f4b50059f0fdc785128a57dd9fdce026/Cython-0.29.14-cp37-cp37m-manylinux1_x86_64.whl (2.1MB)
#      |████████████████████████████████| 2.1MB 24.4MB/s
# Requirement already satisfied: h5py>=2.6 in /opt/conda/lib/python3.7/site-packages (from ludwig) (2.10.0)
# Requirement already satisfied: numpy>=1.15 in /opt/conda/lib/python3.7/site-packages (from ludwig) (1.18.1)
# Requirement already satisfied: pandas>=0.19 in /opt/conda/lib/python3.7/site-packages (from ludwig) (0.25.3)
# Requirement already satisfied: scipy>=0.18 in /opt/conda/lib/python3.7/site-packages (from ludwig) (1.4.1)
# Collecting tabulate>=0.7
#   Downloading https://files.pythonhosted.org/packages/c4/41/523f6a05e6dc3329a5660f6a81254c6cd87e5cfb5b7482bae3391d86ec3a/tabulate-0.8.6.tar.gz (45kB)
#      |████████████████████████████████| 51kB 20.3MB/s
# Collecting scikit-learn
#   Downloading https://files.pythonhosted.org/packages/73/db/7d8204ddba84ab5d1e4fd1af8f82bbe39c589488bee71e45c662f4144010/scikit_learn-0.22.1-cp37-cp37m-manylinux1_x86_64.whl (7.0MB)
#      |████████████████████████████████| 7.0MB 41.7MB/s
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.7/site-packages (from ludwig) (4.40.0)
# Collecting tensorflow==1.14.0
#   Downloading https://files.pythonhosted.org/packages/f4/28/96efba1a516cdacc2e2d6d081f699c001d414cc8ca3250e6d59ae657eb2b/tensorflow-1.14.0-cp37-cp37m-manylinux1_x86_64.whl (109.3MB)
#      |████████████████████████████████| 109.3MB 272kB/s
# Requirement already satisfied: PyYAML>=3.12 in /opt/conda/lib/python3.7/site-packages (from ludwig) (5.3)
# Requirement already satisfied: absl-py in /opt/conda/lib/python3.7/site-packages (from ludwig) (0.9.0)
# Requirement already satisfied: six in /opt/conda/lib/python3.7/site-packages (from h5py>=2.6->ludwig) (1.13.0)
# Requirement already satisfied: pytz>=2017.2 in /opt/conda/lib/python3.7/site-packages (from pandas>=0.19->ludwig) (2019.3)
# Requirement already satisfied: python-dateutil>=2.6.1 in /opt/conda/lib/python3.7/site-packages (from pandas>=0.19->ludwig) (2.8.1)
# Collecting joblib>=0.11
#   Downloading https://files.pythonhosted.org/packages/28/5c/cf6a2b65a321c4a209efcdf64c2689efae2cb62661f8f6f4bb28547cf1bf/joblib-0.14.1-py2.py3-none-any.whl (294kB)
#      |████████████████████████████████| 296kB 57.8MB/s
# Requirement already satisfied: gast>=0.2.0 in /opt/conda/lib/python3.7/site-packages (from tensorflow==1.14.0->ludwig) (0.3.3)
# Requirement already satisfied: wheel>=0.26 in /opt/conda/lib/python3.7/site-packages (from tensorflow==1.14.0->ludwig) (0.33.6)
# Collecting tensorboard<1.15.0,>=1.14.0
#   Downloading https://files.pythonhosted.org/packages/91/2d/2ed263449a078cd9c8a9ba50ebd50123adf1f8cfbea1492f9084169b89d9/tensorboard-1.14.0-py3-none-any.whl (3.1MB)
#      |████████████████████████████████| 3.2MB 47.5MB/s
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/lib/python3.7/site-packages (from tensorflow==1.14.0->ludwig) (1.1.0)
# Collecting google-pasta>=0.1.6
#   Downloading https://files.pythonhosted.org/packages/c3/fd/1e86bc4837cc9a3a5faf3db9b1854aa04ad35b5f381f9648fbe81a6f94e4/google_pasta-0.1.8-py3-none-any.whl (57kB)
#      |████████████████████████████████| 61kB 23.1MB/s
# Requirement already satisfied: astor>=0.6.0 in /opt/conda/lib/python3.7/site-packages (from tensorflow==1.14.0->ludwig) (0.8.1)
# Collecting wrapt>=1.11.1
#   Downloading https://files.pythonhosted.org/packages/23/84/323c2415280bc4fc880ac5050dddfb3c8062c2552b34c2e512eb4aa68f79/wrapt-1.11.2.tar.gz
# Requirement already satisfied: protobuf>=3.6.1 in /opt/conda/lib/python3.7/site-packages (from tensorflow==1.14.0->ludwig) (3.11.3)
# Requirement already satisfied: grpcio>=1.8.6 in /opt/conda/lib/python3.7/site-packages (from tensorflow==1.14.0->ludwig) (1.26.0)
# Collecting tensorflow-estimator<1.15.0rc0,>=1.14.0rc0
#   Downloading https://files.pythonhosted.org/packages/3c/d5/21860a5b11caf0678fbc8319341b0ae21a07156911132e0e71bffed0510d/tensorflow_estimator-1.14.0-py2.py3-none-any.whl (488kB)
#      |████████████████████████████████| 491kB 53.6MB/s
# Requirement already satisfied: keras-applications>=1.0.6 in /opt/conda/lib/python3.7/site-packages (from tensorflow==1.14.0->ludwig) (1.0.8)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /opt/conda/lib/python3.7/site-packages (from tensorflow==1.14.0->ludwig) (1.1.0)
# Requirement already satisfied: setuptools>=41.0.0 in /opt/conda/lib/python3.7/site-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow==1.14.0->ludwig) (42.0.2.post20191201)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.7/site-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow==1.14.0->ludwig) (3.1.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /opt/conda/lib/python3.7/site-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow==1.14.0->ludwig) (0.16.1)
# Building wheels for collected packages: ludwig, tabulate, wrapt
# done
#   Created wheel for ludwig: filename=ludwig-0.2.1-cp37-none-any.whl size=226574 sha256=fc0f390f0e0b4ce3d42e00ab3427e0fa34003454649f02f777660433a831938d
#   Stored in directory: /home/jovyan/.cache/pip/wheels/fc/5d/fd/3796fa772d73a3c0888e78346f28f54100e5d5ef5562890426
# done
#   Created wheel for tabulate: filename=tabulate-0.8.6-cp37-none-any.whl size=23274 sha256=4386d56949d50c9a9b62eb205bf7018fe421f9c121366b392fa037148bbf26a6
#   Stored in directory: /home/jovyan/.cache/pip/wheels/9c/9b/f4/eb243fdb89676ec00588e8c54bb54360724c06e7fafe95278e
# done
#   Created wheel for wrapt: filename=wrapt-1.11.2-cp37-none-any.whl size=19592 sha256=b627acd25f06a54bfa5381b3e89ffd60276f95219eb3a2e9f325b15d339a6be7
#   Stored in directory: /home/jovyan/.cache/pip/wheels/d7/de/2e/efa132238792efb6459a96e85916ef8597fcb3d2ae51590dfd
# Successfully built ludwig tabulate wrapt
# Installing collected packages: Cython, tabulate, joblib, scikit-learn, tensorboard, google-pasta, wrapt, tensorflow-estimator, tensorflow, ludwig
#   Found existing installation: tensorboard 1.13.1
#     Uninstalling tensorboard-1.13.1:
#       Successfully uninstalled tensorboard-1.13.1
#   Found existing installation: tensorflow-estimator 1.13.0
#     Uninstalling tensorflow-estimator-1.13.0:
#       Successfully uninstalled tensorflow-estimator-1.13.0
#   Found existing installation: tensorflow 1.13.1
#     Uninstalling tensorflow-1.13.1:
#       Successfully uninstalled tensorflow-1.13.1
# Successfully installed Cython-0.29.14 google-pasta-0.1.8 joblib-0.14.1 ludwig-0.2.1 scikit-learn-0.22.1 tabulate-0.8.6 tensorboard-1.14.0 tensorflow-1.14.0 tensorflow-estimator-1.14.0 wrapt-1.11.2
# Requirement already satisfied: ludwig[viz] in /opt/conda/lib/python3.7/site-packages (0.2.1)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.7/site-packages (from ludwig[viz]) (0.22.1)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.7/site-packages (from ludwig[viz]) (4.40.0)
# Requirement already satisfied: tensorflow==1.14.0 in /opt/conda/lib/python3.7/site-packages (from ludwig[viz]) (1.14.0)
# Requirement already satisfied: tabulate>=0.7 in /opt/conda/lib/python3.7/site-packages (from ludwig[viz]) (0.8.6)
# Requirement already satisfied: absl-py in /opt/conda/lib/python3.7/site-packages (from ludwig[viz]) (0.9.0)
# Requirement already satisfied: scipy>=0.18 in /opt/conda/lib/python3.7/site-packages (from ludwig[viz]) (1.4.1)
# Requirement already satisfied: PyYAML>=3.12 in /opt/conda/lib/python3.7/site-packages (from ludwig[viz]) (5.3)
# Requirement already satisfied: pandas>=0.19 in /opt/conda/lib/python3.7/site-packages (from ludwig[viz]) (0.25.3)
# Requirement already satisfied: Cython>=0.25 in /opt/conda/lib/python3.7/site-packages (from ludwig[viz]) (0.29.14)
# Requirement already satisfied: h5py>=2.6 in /opt/conda/lib/python3.7/site-packages (from ludwig[viz]) (2.10.0)
# Requirement already satisfied: numpy>=1.15 in /opt/conda/lib/python3.7/site-packages (from ludwig[viz]) (1.18.1)
# Collecting seaborn>=0.7; extra == "viz"
#   Downloading https://files.pythonhosted.org/packages/70/bd/5e6bf595fe6ee0f257ae49336dd180768c1ed3d7c7155b2fdf894c1c808a/seaborn-0.10.0-py3-none-any.whl (215kB)
#      |████████████████████████████████| 225kB 10.5MB/s
# Collecting matplotlib>=3.0; extra == "viz"
#   Downloading https://files.pythonhosted.org/packages/4c/9b/35ab3469fd1509f7636a344940569ebfd33239673fd2318e80b4700a257c/matplotlib-3.1.3-cp37-cp37m-manylinux1_x86_64.whl (13.1MB)
#      |████████████████████████████████| 13.1MB 28.9MB/s
# Requirement already satisfied: joblib>=0.11 in /opt/conda/lib/python3.7/site-packages (from scikit-learn->ludwig[viz]) (0.14.1)
# Requirement already satisfied: tensorflow-estimator<1.15.0rc0,>=1.14.0rc0 in /opt/conda/lib/python3.7/site-packages (from tensorflow==1.14.0->ludwig[viz]) (1.14.0)
# Requirement already satisfied: gast>=0.2.0 in /opt/conda/lib/python3.7/site-packages (from tensorflow==1.14.0->ludwig[viz]) (0.3.3)
# Requirement already satisfied: google-pasta>=0.1.6 in /opt/conda/lib/python3.7/site-packages (from tensorflow==1.14.0->ludwig[viz]) (0.1.8)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /opt/conda/lib/python3.7/site-packages (from tensorflow==1.14.0->ludwig[viz]) (1.1.0)
# Requirement already satisfied: protobuf>=3.6.1 in /opt/conda/lib/python3.7/site-packages (from tensorflow==1.14.0->ludwig[viz]) (3.11.3)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/lib/python3.7/site-packages (from tensorflow==1.14.0->ludwig[viz]) (1.1.0)
# Requirement already satisfied: grpcio>=1.8.6 in /opt/conda/lib/python3.7/site-packages (from tensorflow==1.14.0->ludwig[viz]) (1.26.0)
# Requirement already satisfied: wheel>=0.26 in /opt/conda/lib/python3.7/site-packages (from tensorflow==1.14.0->ludwig[viz]) (0.33.6)
# Requirement already satisfied: wrapt>=1.11.1 in /opt/conda/lib/python3.7/site-packages (from tensorflow==1.14.0->ludwig[viz]) (1.11.2)
# Requirement already satisfied: keras-applications>=1.0.6 in /opt/conda/lib/python3.7/site-packages (from tensorflow==1.14.0->ludwig[viz]) (1.0.8)
# Requirement already satisfied: tensorboard<1.15.0,>=1.14.0 in /opt/conda/lib/python3.7/site-packages (from tensorflow==1.14.0->ludwig[viz]) (1.14.0)
# Requirement already satisfied: astor>=0.6.0 in /opt/conda/lib/python3.7/site-packages (from tensorflow==1.14.0->ludwig[viz]) (0.8.1)
# Requirement already satisfied: six>=1.10.0 in /opt/conda/lib/python3.7/site-packages (from tensorflow==1.14.0->ludwig[viz]) (1.13.0)
# Requirement already satisfied: python-dateutil>=2.6.1 in /opt/conda/lib/python3.7/site-packages (from pandas>=0.19->ludwig[viz]) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /opt/conda/lib/python3.7/site-packages (from pandas>=0.19->ludwig[viz]) (2019.3)
# Collecting pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.1
#   Downloading https://files.pythonhosted.org/packages/5d/bc/1e58593167fade7b544bfe9502a26dc860940a79ab306e651e7f13be68c2/pyparsing-2.4.6-py2.py3-none-any.whl (67kB)
#      |████████████████████████████████| 71kB 23.7MB/s
# Collecting cycler>=0.10
#   Downloading https://files.pythonhosted.org/packages/f7/d2/e07d3ebb2bd7af696440ce7e754c59dd546ffe1bbe732c8ab68b9c834e61/cycler-0.10.0-py2.py3-none-any.whl
# Collecting kiwisolver>=1.0.1
#   Downloading https://files.pythonhosted.org/packages/93/f8/518fb0bb89860eea6ff1b96483fbd9236d5ee991485d0f3eceff1770f654/kiwisolver-1.1.0-cp37-cp37m-manylinux1_x86_64.whl (90kB)
#      |████████████████████████████████| 92kB 29.7MB/s
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.7/site-packages (from protobuf>=3.6.1->tensorflow==1.14.0->ludwig[viz]) (42.0.2.post20191201)
# Requirement already satisfied: werkzeug>=0.11.15 in /opt/conda/lib/python3.7/site-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow==1.14.0->ludwig[viz]) (0.16.1)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.7/site-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow==1.14.0->ludwig[viz]) (3.1.1)
# Installing collected packages: pyparsing, cycler, kiwisolver, matplotlib, seaborn
# Successfully installed cycler-0.10.0 kiwisolver-1.1.0 matplotlib-3.1.3 pyparsing-2.4.6 seaborn-0.10.0

# %% [markdown]
# ## Import required libraries

# %%
import warnings
warnings.simplefilter('ignore')
from ludwig.api import LudwigModel
from ludwig.utils.data_utils import load_json
from ludwig.visualize import learning_curves
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll.stochastic import rng_from_seed
import logging
import shutil
import tempfile
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %% [markdown]
# ## Retrieve data for training

# %%
raw_df = pd.read_csv('winequalityN.csv')
raw_df.shape
# Out:
# (6497, 13)

# %% [markdown]
# ## Standardize column names to replace spaces(" ") with underscore("_")

# %%
new_col = []
for i in range(len(raw_df.columns)):
    new_col.append(raw_df.columns[i].replace(' ', '_'))
    
raw_df.columns = new_col

# %% [markdown]
# ## Data Set Overview

# %%
raw_df.dtypes
# Out:
# type                     object
# fixed_acidity           float64
# volatile_acidity        float64
# citric_acid             float64
# residual_sugar          float64
# chlorides               float64
# free_sulfur_dioxide     float64
# total_sulfur_dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %% [markdown]
# ## Create training and test data sets

# %%
train_df, vald_df = train_test_split(raw_df, test_size = 0.2, random_state=13, stratify=raw_df['quality'])
print(train_df.shape, vald_df.shape)
# Out:
# (5197, 13) (1300, 13)

# %%
train_df['quality'].value_counts().sort_index()
# Out:
# 3      24
# 4     173
# 5    1710
# 6    2269
# 7     863
# 8     154
# 9       4
# Name: quality, dtype: int64

# %%
vald_df['quality'].value_counts().sort_index()
# Out:
# 3      6
# 4     43
# 5    428
# 6    567
# 7    216
# 8     39
# 9      1
# Name: quality, dtype: int64

# %%
# isolate the predictor variables only
predictor_vars = list(set(raw_df.columns) - set(['quality']))

#extract categorical variables
categorical_vars = []
for p in predictor_vars:
    if raw_df[p].dtype == 'object':
        categorical_vars.append(p)
        
print("categorical variables:", categorical_vars,'\n')

# get numerical variables
numerical_vars = list(set(predictor_vars) - set(categorical_vars))

print("numerical variables:", numerical_vars,"\n")
# Out:
# categorical variables: ['type']
#
# numerical variables: ['sulphates', 'residual_sugar', 'volatile_acidity', 'citric_acid', 'fixed_acidity', 'pH', 'density', 'total_sulfur_dioxide', 'alcohol', 'chlorides', 'free_sulfur_dioxide']

# %%
train_df.describe().T
# Out:
#                        count        mean        std      min      25%  \
# fixed_acidity         5189.0    7.198824   1.282347  3.80000   6.4000
# volatile_acidity      5191.0    0.338963   0.165157  0.08000   0.2300
# citric_acid           5194.0    0.319174   0.146128  0.00000   0.2500
# residual_sugar        5195.0    5.424562   4.762894  0.60000   1.8000
# chlorides             5195.0    0.056116   0.035789  0.00900   0.0380
# free_sulfur_dioxide   5197.0   30.656821  17.912418  1.00000  17.0000
# total_sulfur_dioxide  5197.0  116.046180  56.504786  6.00000  78.0000
# density               5197.0    0.994672   0.003008  0.98711   0.9923
# pH                    5189.0    3.218979   0.160672  2.72000   3.1100
# sulphates             5193.0    0.530924   0.147341  0.22000   0.4300
# alcohol               5197.0   10.492117   1.187004  8.00000   9.5000
# quality               5197.0    5.818164   0.873126  3.00000   5.0000
#
#                            50%       75%        max
# fixed_acidity           7.0000    7.7000   15.60000
# volatile_acidity        0.2900    0.4000    1.58000
# citric_acid             0.3100    0.4000    1.66000
# residual_sugar          3.0000    8.0000   65.80000
# chlorides               0.0470    0.0640    0.61100
# free_sulfur_dioxide    29.0000   42.0000  289.00000
# total_sulfur_dioxide  119.0000  156.0000  440.00000
# density                 0.9948    0.9969    1.03898
# pH                      3.2100    3.3200    4.01000
# sulphates               0.5100    0.6000    2.00000
# alcohol                10.3000   11.3000   14.20000
# quality                 6.0000    6.0000    9.00000

# %%
for p in categorical_vars:
    print("unique values for",p,"is",train_df[p].nunique())
# Out:
# unique values for type is 2

# %% [markdown]
# ## Create model definition

# %%
# template for model definition
model_definition = {'input_features':[], 'output_features': [], 'training':{}}

# setup input features for categorical variables
for p in categorical_vars:
    a_feature = {'name': p.replace(' ','_'), 'type': 'category', 'representation': 'sparse'}
    model_definition['input_features'].append(a_feature)


# setup input features for numerical variables
for p in numerical_vars:
    a_feature = {'name': p.replace(' ','_'), 'type': 'numerical', 
                'preprocessing': {'missing_value_strategy': 'fill_with_mean', 'normalization': 'zscore'}}
    model_definition['input_features'].append(a_feature)

# set up output variable
model_definition['output_features'].append({'name': 'quality', 'type':'category'})

# %%
# View the model defintion
print("model definition:")
model_definition
# Out:
# model definition:
# {'input_features': [{'name': 'type',
#    'type': 'category',
#    'representation': 'sparse'},
#   {'name': 'sulphates',
#    'type': 'numerical',
#    'preprocessing': {'missing_value_strategy': 'fill_with_mean',
#     'normalization': 'zscore'}},
#   {'name': 'residual_sugar',
#    'type': 'numerical',
#    'preprocessing': {'missing_value_strategy': 'fill_with_mean',
#     'normalization': 'zscore'}},
#   {'name': 'volatile_acidity',
#    'type': 'numerical',
#    'preprocessing': {'missing_value_strategy': 'fill_with_mean',
#     'normalization': 'zscore'}},
#   {'name': 'citric_acid',
#    'type': 'numerical',
#    'preprocessing': {'missing_value_strategy': 'fill_with_mean',
#     'normalization': 'zscore'}},
#   {'name': 'fixed_acidity',
#    'type': 'numerical',
#    'preprocessing': {'missing_value_strategy': 'fill_with_mean',
#     'normalization': 'zscore'}},
#   {'name': 'pH',
#    'type': 'numerical',
#    'preprocessing': {'missing_value_strategy': 'fill_with_mean',
#     'normalization': 'zscore'}},
#   {'name': 'density',
#    'type': 'numerical',
#    'preprocessing': {'missing_value_strategy': 'fill_with_mean',
#     'normalization': 'zscore'}},
#   {'name': 'total_sulfur_dioxide',
#    'type': 'numerical',
#    'preprocessing': {'missing_value_strategy': 'fill_with_mean',
#     'normalization': 'zscore'}},
#   {'name': 'alcohol',
#    'type': 'numerical',
#    'preprocessing': {'missing_value_strategy': 'fill_with_mean',
#     'normalization': 'zscore'}},
#   {'name': 'chlorides',
#    'type': 'numerical',
#    'preprocessing': {'missing_value_strategy': 'fill_with_mean',
#     'normalization': 'zscore'}},
#   {'name': 'free_sulfur_dioxide',
#    'type': 'numerical',
#    'preprocessing': {'missing_value_strategy': 'fill_with_mean',
#     'normalization': 'zscore'}}],
#  'output_features': [{'name': 'quality', 'type': 'category'}],
#  'training': {}}

# %% [markdown]
# ## Define objective function for minimization

# %%
# objective for hyperopt to minimize
def score_model(params):
    
    print(params)
    
    model_definition['training']['learning_rate'] = params['learning_rate']
    model_definition['training']['batch_size'] = params['batch_size']
    model_definition['output_features'][0]['num_fc_layers'] = np.int(params['output_fc_num_layers'])
    model_definition['output_features'][0]['fc_size'] = np.int(params['output_fc_size'])
    
    model = LudwigModel(model_definition,
                        logging_level=logging.WARN)

    with tempfile.TemporaryDirectory() as tmpdirname:
        train_stats = model.train(data_train_df = train_df,
                                data_validation_df = vald_df,
                                skip_save_training_description=True, 
                                skip_save_training_statistics=True, 
                                skip_save_model=True, 
                                skip_save_progress=True,                          
                                skip_save_log=True,
                                skip_save_processed_input=True,
                                output_directory=tmpdirname,
                                random_seed=42)



    model.close()
    
    # return validation loss for last epoch as objective function value
    validation_losses = train_stats['validation']['quality']['loss']
    last_epoch = len(validation_losses)
    
    return {'loss': validation_losses[last_epoch - 1], 'status': STATUS_OK}

# %% [markdown]
# ## Define hyperparameter search space

# %%
SEED=13

# function to calculate batch size
set_batch_size = lambda n: 2**(n + 5)

space = {'learning_rate':  hp.loguniform('learning_rate', np.log(0.0001), np.log(0.01), rng=rng_from_seed(SEED)),
         'batch_size': set_batch_size(hp.randint('batch_size_exponent',3, rng=rng_from_seed(SEED))),
         'output_fc_num_layers': hp.quniform('output_fc_num_layers',1,5,1, rng=rng_from_seed(SEED)),
         'output_fc_size': hp.quniform('output_fc_size',5,200,1, rng=rng_from_seed(SEED))
        }

# %% [markdown]
# ## Determine optimal hyperparameters

# %%
np.random.seed(123)
best = fmin(fn=score_model,
    space=space,
    algo=tpe.suggest,
    max_evals=30)
# Out:
# {'batch_size': 128, 'learning_rate': 0.007873021473212867, 'output_fc_num_layers': 4.0, 'output_fc_size': 96.0}
#   0%|          | 0/30 [00:00<?, ?trial/s, best loss=?]WARNING:tensorflow:From /opt/conda/lib/python3.7/site-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# {'batch_size': 128, 'learning_rate': 0.006459629518833773, 'output_fc_num_layers': 3.0, 'output_fc_size': 120.0}
# {'batch_size': 128, 'learning_rate': 0.008791847061536151, 'output_fc_num_layers': 4.0, 'output_fc_size': 18.0}
# {'batch_size': 32, 'learning_rate': 0.00013260663429940408, 'output_fc_num_layers': 2.0, 'output_fc_size': 139.0}
# {'batch_size': 64, 'learning_rate': 0.0004114537610690335, 'output_fc_num_layers': 3.0, 'output_fc_size': 126.0}
# {'batch_size': 64, 'learning_rate': 0.0024373055713476062, 'output_fc_num_layers': 4.0, 'output_fc_size': 12.0}
# {'batch_size': 128, 'learning_rate': 0.0002485984091808364, 'output_fc_num_layers': 5.0, 'output_fc_size': 19.0}
# {'batch_size': 32, 'learning_rate': 0.006963210680877398, 'output_fc_num_layers': 1.0, 'output_fc_size': 156.0}
# {'batch_size': 32, 'learning_rate': 0.002645540259571278, 'output_fc_num_layers': 1.0, 'output_fc_size': 93.0}
# {'batch_size': 32, 'learning_rate': 0.0014476751851078863, 'output_fc_num_layers': 4.0, 'output_fc_size': 78.0}
# {'batch_size': 128, 'learning_rate': 0.00011276772336549267, 'output_fc_num_layers': 3.0, 'output_fc_size': 64.0}
# {'batch_size': 64, 'learning_rate': 0.00021620917754759214, 'output_fc_num_layers': 3.0, 'output_fc_size': 39.0}
# {'batch_size': 64, 'learning_rate': 0.00010457813008290473, 'output_fc_num_layers': 3.0, 'output_fc_size': 71.0}
# {'batch_size': 128, 'learning_rate': 0.007302997245937265, 'output_fc_num_layers': 2.0, 'output_fc_size': 196.0}
# {'batch_size': 64, 'learning_rate': 0.002095363167557452, 'output_fc_num_layers': 3.0, 'output_fc_size': 47.0}
# {'batch_size': 128, 'learning_rate': 0.0006309982432396125, 'output_fc_num_layers': 5.0, 'output_fc_size': 163.0}
# {'batch_size': 64, 'learning_rate': 0.0003191518594637119, 'output_fc_num_layers': 5.0, 'output_fc_size': 135.0}
# {'batch_size': 32, 'learning_rate': 0.000996777616851434, 'output_fc_num_layers': 2.0, 'output_fc_size': 117.0}
# {'batch_size': 128, 'learning_rate': 0.003557560006591247, 'output_fc_num_layers': 4.0, 'output_fc_size': 152.0}
# {'batch_size': 32, 'learning_rate': 0.00368535037094493, 'output_fc_num_layers': 4.0, 'output_fc_size': 167.0}
# {'batch_size': 32, 'learning_rate': 0.0001787212331983303, 'output_fc_num_layers': 2.0, 'output_fc_size': 194.0}
# {'batch_size': 32, 'learning_rate': 0.00015819416241546864, 'output_fc_num_layers': 2.0, 'output_fc_size': 193.0}
# {'batch_size': 32, 'learning_rate': 0.0001444338111083431, 'output_fc_num_layers': 2.0, 'output_fc_size': 184.0}
# {'batch_size': 32, 'learning_rate': 0.00054196689028665, 'output_fc_num_layers': 1.0, 'output_fc_size': 178.0}
# {'batch_size': 32, 'learning_rate': 0.00012786104418671776, 'output_fc_num_layers': 2.0, 'output_fc_size': 142.0}
# {'batch_size': 32, 'learning_rate': 0.0008968577290087804, 'output_fc_num_layers': 1.0, 'output_fc_size': 177.0}
# {'batch_size': 32, 'learning_rate': 0.0003042641475743343, 'output_fc_num_layers': 2.0, 'output_fc_size': 177.0}
# {'batch_size': 32, 'learning_rate': 0.00010179444022428049, 'output_fc_num_layers': 1.0, 'output_fc_size': 110.0}
# {'batch_size': 32, 'learning_rate': 0.000453722116452508, 'output_fc_num_layers': 2.0, 'output_fc_size': 142.0}
# {'batch_size': 32, 'learning_rate': 0.0001511467064798607, 'output_fc_num_layers': 2.0, 'output_fc_size': 96.0}
# 100%|██████████| 30/30 [08:08<00:00, 16.29s/trial, best loss: 1.025309421832745]

# %%
print('batch size:', set_batch_size(best['batch_size_exponent']),
      ', learning_rate:', best['learning_rate'],
      ', fc_num_layers:', np.int(best['output_fc_num_layers']),
      ', fc_size:', np.int(best['output_fc_size']))
# Out:
# batch size: 32 , learning_rate: 0.00013260663429940408 , fc_num_layers: 2 , fc_size: 139

# %% [markdown]
# ## Train with optimal hyperparameters on the whole data set

# %%
# clean out old results
try:
    shutil.rmtree('./results')
except:
    pass

try:
    shutil.rmtree('./visualizations')
except:
    pass

# %%
# set optimal hyperparameters for training    
model_definition['training']['learning_rate'] = best['learning_rate']
model_definition['training']['batch_size'] = set_batch_size(best['batch_size_exponent'])
model_definition['output_features'][0]['num_fc_layers'] = np.int(best['output_fc_num_layers'])
model_definition['output_features'][0]['fc_size'] = np.int(best['output_fc_size'])


# Define Ludwig model object that drive model training
model = LudwigModel(model_definition,
                    logging_level=logging.INFO)

# initiate model training
opt_stats = model.train(data_df = raw_df,
                        experiment_name='hyperparameter_training',
                        model_name='optimized_model',                        
                        random_seed=42, output_directory="/valohai/outputs/")



model.close()
# Out:
# Experiment name: hyperparameter_training
# Model name: optimized_model
# Output path: /valohai/outputs/hyperparameter_training_optimized_model
#
#
# ludwig_version: '0.2.1'
# command: ('/opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py -f '
#  '/tmp/tmpm04fg4dh.json')
# random_seed: 42
# model_definition: {   'combiner': {'type': 'concat'},
#     'input_features': [   {   'name': 'type',
#                               'representation': 'sparse',
#                               'tied_weights': None,
#                               'type': 'category'},
#                           {   'name': 'sulphates',
#                               'preprocessing': {   'missing_value_strategy': 'fill_with_mean',
#                                                    'normalization': 'zscore'},
#                               'tied_weights': None,
#                               'type': 'numerical'},
#                           {   'name': 'residual_sugar',
#                               'preprocessing': {   'missing_value_strategy': 'fill_with_mean',
#                                                    'normalization': 'zscore'},
#                               'tied_weights': None,
#                               'type': 'numerical'},
#                           {   'name': 'volatile_acidity',
#                               'preprocessing': {   'missing_value_strategy': 'fill_with_mean',
#                                                    'normalization': 'zscore'},
#                               'tied_weights': None,
#                               'type': 'numerical'},
#                           {   'name': 'citric_acid',
#                               'preprocessing': {   'missing_value_strategy': 'fill_with_mean',
#                                                    'normalization': 'zscore'},
#                               'tied_weights': None,
#                               'type': 'numerical'},
#                           {   'name': 'fixed_acidity',
#                               'preprocessing': {   'missing_value_strategy': 'fill_with_mean',
#                                                    'normalization': 'zscore'},
#                               'tied_weights': None,
#                               'type': 'numerical'},
#                           {   'name': 'pH',
#                               'preprocessing': {   'missing_value_strategy': 'fill_with_mean',
#                                                    'normalization': 'zscore'},
#                               'tied_weights': None,
#                               'type': 'numerical'},
#                           {   'name': 'density',
#                               'preprocessing': {   'missing_value_strategy': 'fill_with_mean',
#                                                    'normalization': 'zscore'},
#                               'tied_weights': None,
#                               'type': 'numerical'},
#                           {   'name': 'total_sulfur_dioxide',
#                               'preprocessing': {   'missing_value_strategy': 'fill_with_mean',
#                                                    'normalization': 'zscore'},
#                               'tied_weights': None,
#                               'type': 'numerical'},
#                           {   'name': 'alcohol',
#                               'preprocessing': {   'missing_value_strategy': 'fill_with_mean',
#                                                    'normalization': 'zscore'},
#                               'tied_weights': None,
#                               'type': 'numerical'},
#                           {   'name': 'chlorides',
#                               'preprocessing': {   'missing_value_strategy': 'fill_with_mean',
#                                                    'normalization': 'zscore'},
#                               'tied_weights': None,
#                               'type': 'numerical'},
#                           {   'name': 'free_sulfur_dioxide',
#                               'preprocessing': {   'missing_value_strategy': 'fill_with_mean',
#                                                    'normalization': 'zscore'},
#                               'tied_weights': None,
#                               'type': 'numerical'}],
#     'output_features': [   {   'dependencies': [],
#                                'fc_size': 139,
#                                'loss': {   'class_similarities_temperature': 0,
#                                            'class_weights': 1,
#                                            'confidence_penalty': 0,
#                                            'distortion': 1,
#                                            'labels_smoothing': 0,
#                                            'negative_samples': 0,
#                                            'robust_lambda': 0,
#                                            'sampler': None,
#                                            'type': 'softmax_cross_entropy',
#                                            'unique': False,
#                                            'weight': 1},
#                                'name': 'quality',
#                                'num_fc_layers': 2,
#                                'reduce_dependencies': 'sum',
#                                'reduce_input': 'sum',
#                                'top_k': 3,
#                                'type': 'category'}],
#     'preprocessing': {   'audio': {   'audio_feature': {'type': 'raw'},
#                                       'audio_file_length_limit_in_s': 7.5,
#                                       'in_memory': True,
#                                       'missing_value_strategy': 'backfill',
#                                       'norm': None,
#                                       'padding_value': 0},
#                          'bag': {   'fill_value': '',
#                                     'lowercase': False,
#                                     'missing_value_strategy': 'fill_with_const',
#                                     'most_common': 10000,
#                                     'tokenizer': 'space'},
#                          'binary': {   'fill_value': 0,
#                                        'missing_value_strategy': 'fill_with_const'},
#                          'category': {   'fill_value': '<UNK>',
#                                          'lowercase': False,
#                                          'missing_value_strategy': 'fill_with_const',
#                                          'most_common': 10000},
#                          'date': {   'datetime_format': None,
#                                      'fill_value': '',
#                                      'missing_value_strategy': 'fill_with_const'},
#                          'force_split': False,
#                          'h3': {   'fill_value': 576495936675512319,
#                                    'missing_value_strategy': 'fill_with_const'},
#                          'image': {   'in_memory': True,
#                                       'missing_value_strategy': 'backfill',
#                                       'num_processes': 1,
#                                       'resize_method': 'interpolate',
#                                       'scaling': 'pixel_normalization'},
#                          'numerical': {   'fill_value': 0,
#                                           'missing_value_strategy': 'fill_with_const',
#                                           'normalization': None},
#                          'sequence': {   'fill_value': '',
#                                          'lowercase': False,
#                                          'missing_value_strategy': 'fill_with_const',
#                                          'most_common': 20000,
#                                          'padding': 'right',
#                                          'padding_symbol': '<PAD>',
#                                          'sequence_length_limit': 256,
#                                          'tokenizer': 'space',
#                                          'unknown_symbol': '<UNK>',
#                                          'vocab_file': None},
#                          'set': {   'fill_value': '',
#                                     'lowercase': False,
#                                     'missing_value_strategy': 'fill_with_const',
#                                     'most_common': 10000,
#                                     'tokenizer': 'space'},
#                          'split_probabilities': (0.7, 0.1, 0.2),
#                          'stratify': None,
#                          'text': {   'char_most_common': 70,
#                                      'char_sequence_length_limit': 1024,
#                                      'char_tokenizer': 'characters',
#                                      'char_vocab_file': None,
#                                      'fill_value': '',
#                                      'lowercase': True,
#                                      'missing_value_strategy': 'fill_with_const',
#                                      'padding': 'right',
#                                      'padding_symbol': '<PAD>',
#                                      'unknown_symbol': '<UNK>',
#                                      'word_most_common': 20000,
#                                      'word_sequence_length_limit': 256,
#                                      'word_tokenizer': 'space_punct',
#                                      'word_vocab_file': None},
#                          'timeseries': {   'fill_value': '',
#                                            'missing_value_strategy': 'fill_with_const',
#                                            'padding': 'right',
#                                            'padding_value': 0,
#                                            'timeseries_length_limit': 256,
#                                            'tokenizer': 'space'},
#                          'vector': {   'fill_value': '',
#                                        'missing_value_strategy': 'fill_with_const'}},
#     'training': {   'batch_size': 32,
#                     'bucketing_field': None,
#                     'decay': False,
#                     'decay_rate': 0.96,
#                     'decay_steps': 10000,
#                     'dropout_rate': 0.0,
#                     'early_stop': 5,
#                     'epochs': 100,
#                     'eval_batch_size': 0,
#                     'gradient_clipping': None,
#                     'increase_batch_size_on_plateau': 0,
#                     'increase_batch_size_on_plateau_max': 512,
#                     'increase_batch_size_on_plateau_patience': 5,
#                     'increase_batch_size_on_plateau_rate': 2,
#                     'learning_rate': 0.00013260663429940408,
#                     'learning_rate_warmup_epochs': 1,
#                     'optimizer': {   'beta1': 0.9,
#                                      'beta2': 0.999,
#                                      'epsilon': 1e-08,
#                                      'type': 'adam'},
#                     'reduce_learning_rate_on_plateau': 0,
#                     'reduce_learning_rate_on_plateau_patience': 5,
#                     'reduce_learning_rate_on_plateau_rate': 0.5,
#                     'regularization_lambda': 0,
#                     'regularizer': 'l2',
#                     'staircase': False,
#                     'validation_field': 'combined',
#                     'validation_measure': 'loss'}}
#
#
# Using full dataframe
# Building dataset (it may take a while)
# Training set: 4588
# Validation set: 612
# Test set: 1297
#
# ╒══════════╕
# │ TRAINING │
# ╘══════════╛
#
#
# Epoch   1
# Took 0.9991s
# ╒═══════════╤════════╤════════════╤═════════════╕
# │ quality   │   loss │   accuracy │   hits_at_k │
# ╞═══════════╪════════╪════════════╪═════════════╡
# │ train     │ 1.4561 │     0.4104 │      0.9196 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ vali      │ 1.4052 │     0.4248 │      0.9281 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ test      │ 1.4615 │     0.4241 │      0.9214 │
# ╘═══════════╧════════╧════════════╧═════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch   2
# Took 0.5746s
# ╒═══════════╤════════╤════════════╤═════════════╕
# │ quality   │   loss │   accuracy │   hits_at_k │
# ╞═══════════╪════════╪════════════╪═════════════╡
# │ train     │ 1.2153 │     0.5024 │      0.9398 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ vali      │ 1.1620 │     0.5000 │      0.9493 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ test      │ 1.2107 │     0.5019 │      0.9391 │
# ╘═══════════╧════════╧════════════╧═════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch   3
# Took 0.5408s
# ╒═══════════╤════════╤════════════╤═════════════╕
# │ quality   │   loss │   accuracy │   hits_at_k │
# ╞═══════════╪════════╪════════════╪═════════════╡
# │ train     │ 1.1464 │     0.5323 │      0.9492 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ vali      │ 1.1024 │     0.5212 │      0.9526 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ test      │ 1.1454 │     0.5305 │      0.9429 │
# ╘═══════════╧════════╧════════════╧═════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch   4
# Took 0.5373s
# ╒═══════════╤════════╤════════════╤═════════════╕
# │ quality   │   loss │   accuracy │   hits_at_k │
# ╞═══════════╪════════╪════════════╪═════════════╡
# │ train     │ 1.1095 │     0.5503 │      0.9527 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ vali      │ 1.0773 │     0.5408 │      0.9608 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ test      │ 1.1153 │     0.5428 │      0.9514 │
# ╘═══════════╧════════╧════════════╧═════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch   5
# Took 0.5509s
# ╒═══════════╤════════╤════════════╤═════════════╕
# │ quality   │   loss │   accuracy │   hits_at_k │
# ╞═══════════╪════════╪════════════╪═════════════╡
# │ train     │ 1.0850 │     0.5606 │      0.9544 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ vali      │ 1.0641 │     0.5539 │      0.9608 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ test      │ 1.0976 │     0.5551 │      0.9584 │
# ╘═══════════╧════════╧════════════╧═════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch   6
# Took 0.5499s
# ╒═══════════╤════════╤════════════╤═════════════╕
# │ quality   │   loss │   accuracy │   hits_at_k │
# ╞═══════════╪════════╪════════════╪═════════════╡
# │ train     │ 1.0663 │     0.5691 │      0.9566 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ vali      │ 1.0554 │     0.5556 │      0.9624 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ test      │ 1.0856 │     0.5590 │      0.9607 │
# ╘═══════════╧════════╧════════════╧═════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch   7
# Took 0.5449s
# ╒═══════════╤════════╤════════════╤═════════════╕
# │ quality   │   loss │   accuracy │   hits_at_k │
# ╞═══════════╪════════╪════════════╪═════════════╡
# │ train     │ 1.0510 │     0.5732 │      0.9577 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ vali      │ 1.0488 │     0.5507 │      0.9624 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ test      │ 1.0766 │     0.5598 │      0.9584 │
# ╘═══════════╧════════╧════════════╧═════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch   8
# Took 0.5797s
# ╒═══════════╤════════╤════════════╤═════════════╕
# │ quality   │   loss │   accuracy │   hits_at_k │
# ╞═══════════╪════════╪════════════╪═════════════╡
# │ train     │ 1.0381 │     0.5778 │      0.9592 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ vali      │ 1.0434 │     0.5507 │      0.9641 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ test      │ 1.0690 │     0.5605 │      0.9568 │
# ╘═══════════╧════════╧════════════╧═════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch   9
# Took 0.5451s
# ╒═══════════╤════════╤════════════╤═════════════╕
# │ quality   │   loss │   accuracy │   hits_at_k │
# ╞═══════════╪════════╪════════════╪═════════════╡
# │ train     │ 1.0270 │     0.5817 │      0.9612 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ vali      │ 1.0389 │     0.5474 │      0.9641 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ test      │ 1.0625 │     0.5598 │      0.9576 │
# ╘═══════════╧════════╧════════════╧═════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  10
# Took 0.5737s
# ╒═══════════╤════════╤════════════╤═════════════╕
# │ quality   │   loss │   accuracy │   hits_at_k │
# ╞═══════════╪════════╪════════════╪═════════════╡
# │ train     │ 1.0174 │     0.5841 │      0.9619 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ vali      │ 1.0352 │     0.5490 │      0.9641 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ test      │ 1.0572 │     0.5613 │      0.9561 │
# ╘═══════════╧════════╧════════════╧═════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  11
# Took 0.5577s
# ╒═══════════╤════════╤════════════╤═════════════╕
# │ quality   │   loss │   accuracy │   hits_at_k │
# ╞═══════════╪════════╪════════════╪═════════════╡
# │ train     │ 1.0088 │     0.5878 │      0.9632 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ vali      │ 1.0321 │     0.5523 │      0.9641 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ test      │ 1.0528 │     0.5621 │      0.9561 │
# ╘═══════════╧════════╧════════════╧═════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  12
# Took 0.5852s
# ╒═══════════╤════════╤════════════╤═════════════╕
# │ quality   │   loss │   accuracy │   hits_at_k │
# ╞═══════════╪════════╪════════════╪═════════════╡
# │ train     │ 1.0011 │     0.5887 │      0.9632 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ vali      │ 1.0291 │     0.5539 │      0.9641 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ test      │ 1.0487 │     0.5652 │      0.9568 │
# ╘═══════════╧════════╧════════════╧═════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  13
# Took 0.5391s
# ╒═══════════╤════════╤════════════╤═════════════╕
# │ quality   │   loss │   accuracy │   hits_at_k │
# ╞═══════════╪════════╪════════════╪═════════════╡
# │ train     │ 0.9940 │     0.5939 │      0.9643 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ vali      │ 1.0265 │     0.5588 │      0.9641 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ test      │ 1.0451 │     0.5659 │      0.9584 │
# ╘═══════════╧════════╧════════════╧═════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  14
# Took 0.6197s
# ╒═══════════╤════════╤════════════╤═════════════╕
# │ quality   │   loss │   accuracy │   hits_at_k │
# ╞═══════════╪════════╪════════════╪═════════════╡
# │ train     │ 0.9874 │     0.5963 │      0.9645 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ vali      │ 1.0242 │     0.5572 │      0.9657 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ test      │ 1.0419 │     0.5675 │      0.9576 │
# ╘═══════════╧════════╧════════════╧═════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  15
# Took 0.5512s
# ╒═══════════╤════════╤════════════╤═════════════╕
# │ quality   │   loss │   accuracy │   hits_at_k │
# ╞═══════════╪════════╪════════════╪═════════════╡
# │ train     │ 0.9812 │     0.5957 │      0.9643 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ vali      │ 1.0220 │     0.5539 │      0.9657 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ test      │ 1.0389 │     0.5698 │      0.9591 │
# ╘═══════════╧════════╧════════════╧═════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  16
# Took 0.5953s
# ╒═══════════╤════════╤════════════╤═════════════╕
# │ quality   │   loss │   accuracy │   hits_at_k │
# ╞═══════════╪════════╪════════════╪═════════════╡
# │ train     │ 0.9752 │     0.5966 │      0.9645 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ vali      │ 1.0201 │     0.5507 │      0.9657 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ test      │ 1.0362 │     0.5682 │      0.9599 │
# ╘═══════════╧════════╧════════════╧═════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  17
# Took 0.5116s
# ╒═══════════╤════════╤════════════╤═════════════╕
# │ quality   │   loss │   accuracy │   hits_at_k │
# ╞═══════════╪════════╪════════════╪═════════════╡
# │ train     │ 0.9696 │     0.5979 │      0.9647 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ vali      │ 1.0182 │     0.5490 │      0.9673 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ test      │ 1.0338 │     0.5698 │      0.9599 │
# ╘═══════════╧════════╧════════════╧═════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  18
# Took 0.5616s
# ╒═══════════╤════════╤════════════╤═════════════╕
# │ quality   │   loss │   accuracy │   hits_at_k │
# ╞═══════════╪════════╪════════════╪═════════════╡
# │ train     │ 0.9642 │     0.5994 │      0.9643 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ vali      │ 1.0167 │     0.5523 │      0.9690 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ test      │ 1.0317 │     0.5705 │      0.9599 │
# ╘═══════════╧════════╧════════════╧═════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  19
# Took 0.5504s
# ╒═══════════╤════════╤════════════╤═════════════╕
# │ quality   │   loss │   accuracy │   hits_at_k │
# ╞═══════════╪════════╪════════════╪═════════════╡
# │ train     │ 0.9589 │     0.5998 │      0.9643 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ vali      │ 1.0152 │     0.5539 │      0.9690 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ test      │ 1.0299 │     0.5705 │      0.9599 │
# ╘═══════════╧════════╧════════════╧═════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  20
# Took 0.5714s
# ╒═══════════╤════════╤════════════╤═════════════╕
# │ quality   │   loss │   accuracy │   hits_at_k │
# ╞═══════════╪════════╪════════════╪═════════════╡
# │ train     │ 0.9539 │     0.6009 │      0.9643 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ vali      │ 1.0136 │     0.5539 │      0.9690 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ test      │ 1.0278 │     0.5705 │      0.9599 │
# ╘═══════════╧════════╧════════════╧═════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  21
# Took 0.5611s
# ╒═══════════╤════════╤════════════╤═════════════╕
# │ quality   │   loss │   accuracy │   hits_at_k │
# ╞═══════════╪════════╪════════════╪═════════════╡
# │ train     │ 0.9490 │     0.6027 │      0.9651 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ vali      │ 1.0122 │     0.5539 │      0.9690 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ test      │ 1.0259 │     0.5713 │      0.9599 │
# ╘═══════════╧════════╧════════════╧═════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  22
# Took 0.6301s
# ╒═══════════╤════════╤════════════╤═════════════╕
# │ quality   │   loss │   accuracy │   hits_at_k │
# ╞═══════════╪════════╪════════════╪═════════════╡
# │ train     │ 0.9442 │     0.6035 │      0.9651 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ vali      │ 1.0110 │     0.5490 │      0.9722 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ test      │ 1.0242 │     0.5690 │      0.9591 │
# ╘═══════════╧════════╧════════════╧═════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  23
# Took 0.5591s
# ╒═══════════╤════════╤════════════╤═════════════╕
# │ quality   │   loss │   accuracy │   hits_at_k │
# ╞═══════════╪════════╪════════════╪═════════════╡
# │ train     │ 0.9397 │     0.6040 │      0.9653 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ vali      │ 1.0098 │     0.5523 │      0.9739 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ test      │ 1.0225 │     0.5690 │      0.9591 │
# ╘═══════════╧════════╧════════════╧═════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  24
# Took 0.5235s
# ╒═══════════╤════════╤════════════╤═════════════╕
# │ quality   │   loss │   accuracy │   hits_at_k │
# ╞═══════════╪════════╪════════════╪═════════════╡
# │ train     │ 0.9352 │     0.6042 │      0.9656 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ vali      │ 1.0086 │     0.5507 │      0.9739 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ test      │ 1.0207 │     0.5713 │      0.9591 │
# ╘═══════════╧════════╧════════════╧═════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  25
# Took 0.5497s
# ╒═══════════╤════════╤════════════╤═════════════╕
# │ quality   │   loss │   accuracy │   hits_at_k │
# ╞═══════════╪════════╪════════════╪═════════════╡
# │ train     │ 0.9309 │     0.6046 │      0.9671 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ vali      │ 1.0075 │     0.5507 │      0.9739 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ test      │ 1.0192 │     0.5705 │      0.9599 │
# ╘═══════════╧════════╧════════════╧═════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  26
# Took 0.5095s
# ╒═══════════╤════════╤════════════╤═════════════╕
# │ quality   │   loss │   accuracy │   hits_at_k │
# ╞═══════════╪════════╪════════════╪═════════════╡
# │ train     │ 0.9267 │     0.6066 │      0.9673 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ vali      │ 1.0066 │     0.5523 │      0.9739 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ test      │ 1.0178 │     0.5721 │      0.9599 │
# ╘═══════════╧════════╧════════════╧═════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  27
# Took 0.5431s
# ╒═══════════╤════════╤════════════╤═════════════╕
# │ quality   │   loss │   accuracy │   hits_at_k │
# ╞═══════════╪════════╪════════════╪═════════════╡
# │ train     │ 0.9227 │     0.6077 │      0.9677 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ vali      │ 1.0055 │     0.5556 │      0.9739 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ test      │ 1.0162 │     0.5713 │      0.9599 │
# ╘═══════════╧════════╧════════════╧═════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  28
# Took 0.5663s
# ╒═══════════╤════════╤════════════╤═════════════╕
# │ quality   │   loss │   accuracy │   hits_at_k │
# ╞═══════════╪════════╪════════════╪═════════════╡
# │ train     │ 0.9187 │     0.6105 │      0.9677 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ vali      │ 1.0048 │     0.5556 │      0.9739 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ test      │ 1.0149 │     0.5721 │      0.9599 │
# ╘═══════════╧════════╧════════════╧═════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  29
# Took 0.5452s
# ╒═══════════╤════════╤════════════╤═════════════╕
# │ quality   │   loss │   accuracy │   hits_at_k │
# ╞═══════════╪════════╪════════════╪═════════════╡
# │ train     │ 0.9149 │     0.6149 │      0.9680 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ vali      │ 1.0041 │     0.5572 │      0.9739 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ test      │ 1.0139 │     0.5729 │      0.9599 │
# ╘═══════════╧════════╧════════════╧═════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  30
# Took 0.5531s
# ╒═══════════╤════════╤════════════╤═════════════╕
# │ quality   │   loss │   accuracy │   hits_at_k │
# ╞═══════════╪════════╪════════════╪═════════════╡
# │ train     │ 0.9111 │     0.6162 │      0.9686 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ vali      │ 1.0028 │     0.5572 │      0.9739 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ test      │ 1.0128 │     0.5721 │      0.9599 │
# ╘═══════════╧════════╧════════════╧═════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  31
# Took 0.5360s
# ╒═══════════╤════════╤════════════╤═════════════╕
# │ quality   │   loss │   accuracy │   hits_at_k │
# ╞═══════════╪════════╪════════════╪═════════════╡
# │ train     │ 0.9075 │     0.6157 │      0.9690 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ vali      │ 1.0022 │     0.5605 │      0.9739 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ test      │ 1.0119 │     0.5736 │      0.9607 │
# ╘═══════════╧════════╧════════════╧═════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  32
# Took 0.5014s
# ╒═══════════╤════════╤════════════╤═════════════╕
# │ quality   │   loss │   accuracy │   hits_at_k │
# ╞═══════════╪════════╪════════════╪═════════════╡
# │ train     │ 0.9039 │     0.6166 │      0.9697 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ vali      │ 1.0013 │     0.5605 │      0.9739 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ test      │ 1.0106 │     0.5759 │      0.9614 │
# ╘═══════════╧════════╧════════════╧═════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  33
# Took 0.5654s
# ╒═══════════╤════════╤════════════╤═════════════╕
# │ quality   │   loss │   accuracy │   hits_at_k │
# ╞═══════════╪════════╪════════════╪═════════════╡
# │ train     │ 0.9003 │     0.6192 │      0.9704 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ vali      │ 1.0006 │     0.5588 │      0.9739 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ test      │ 1.0099 │     0.5783 │      0.9614 │
# ╘═══════════╧════════╧════════════╧═════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  34
# Took 0.5933s
# ╒═══════════╤════════╤════════════╤═════════════╕
# │ quality   │   loss │   accuracy │   hits_at_k │
# ╞═══════════╪════════╪════════════╪═════════════╡
# │ train     │ 0.8968 │     0.6227 │      0.9704 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ vali      │ 0.9998 │     0.5605 │      0.9739 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ test      │ 1.0092 │     0.5790 │      0.9614 │
# ╘═══════════╧════════╧════════════╧═════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  35
# Took 0.5444s
# ╒═══════════╤════════╤════════════╤═════════════╕
# │ quality   │   loss │   accuracy │   hits_at_k │
# ╞═══════════╪════════╪════════════╪═════════════╡
# │ train     │ 0.8934 │     0.6242 │      0.9708 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ vali      │ 0.9992 │     0.5605 │      0.9739 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ test      │ 1.0084 │     0.5783 │      0.9614 │
# ╘═══════════╧════════╧════════════╧═════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  36
# Took 0.5432s
# ╒═══════════╤════════╤════════════╤═════════════╕
# │ quality   │   loss │   accuracy │   hits_at_k │
# ╞═══════════╪════════╪════════════╪═════════════╡
# │ train     │ 0.8899 │     0.6258 │      0.9706 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ vali      │ 0.9987 │     0.5588 │      0.9739 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ test      │ 1.0079 │     0.5775 │      0.9599 │
# ╘═══════════╧════════╧════════════╧═════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  37
# Took 0.5669s
# ╒═══════════╤════════╤════════════╤═════════════╕
# │ quality   │   loss │   accuracy │   hits_at_k │
# ╞═══════════╪════════╪════════════╪═════════════╡
# │ train     │ 0.8866 │     0.6288 │      0.9710 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ vali      │ 0.9981 │     0.5605 │      0.9739 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ test      │ 1.0072 │     0.5790 │      0.9599 │
# ╘═══════════╧════════╧════════════╧═════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  38
# Took 0.5346s
# ╒═══════════╤════════╤════════════╤═════════════╕
# │ quality   │   loss │   accuracy │   hits_at_k │
# ╞═══════════╪════════╪════════════╪═════════════╡
# │ train     │ 0.8833 │     0.6314 │      0.9710 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ vali      │ 0.9976 │     0.5605 │      0.9739 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ test      │ 1.0066 │     0.5813 │      0.9607 │
# ╘═══════════╧════════╧════════════╧═════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  39
# Took 0.5921s
# ╒═══════════╤════════╤════════════╤═════════════╕
# │ quality   │   loss │   accuracy │   hits_at_k │
# ╞═══════════╪════════╪════════════╪═════════════╡
# │ train     │ 0.8801 │     0.6319 │      0.9712 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ vali      │ 0.9969 │     0.5621 │      0.9739 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ test      │ 1.0062 │     0.5806 │      0.9607 │
# ╘═══════════╧════════╧════════════╧═════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  40
# Took 0.5488s
# ╒═══════════╤════════╤════════════╤═════════════╕
# │ quality   │   loss │   accuracy │   hits_at_k │
# ╞═══════════╪════════╪════════════╪═════════════╡
# │ train     │ 0.8768 │     0.6338 │      0.9712 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ vali      │ 0.9963 │     0.5621 │      0.9755 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ test      │ 1.0057 │     0.5798 │      0.9607 │
# ╘═══════════╧════════╧════════════╧═════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  41
# Took 0.5701s
# ╒═══════════╤════════╤════════════╤═════════════╕
# │ quality   │   loss │   accuracy │   hits_at_k │
# ╞═══════════╪════════╪════════════╪═════════════╡
# │ train     │ 0.8737 │     0.6356 │      0.9710 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ vali      │ 0.9957 │     0.5605 │      0.9755 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ test      │ 1.0052 │     0.5775 │      0.9607 │
# ╘═══════════╧════════╧════════════╧═════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  42
# Took 0.5942s
# ╒═══════════╤════════╤════════════╤═════════════╕
# │ quality   │   loss │   accuracy │   hits_at_k │
# ╞═══════════╪════════╪════════════╪═════════════╡
# │ train     │ 0.8705 │     0.6386 │      0.9714 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ vali      │ 0.9952 │     0.5605 │      0.9739 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ test      │ 1.0049 │     0.5783 │      0.9607 │
# ╘═══════════╧════════╧════════════╧═════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  43
# Took 0.5362s
# ╒═══════════╤════════╤════════════╤═════════════╕
# │ quality   │   loss │   accuracy │   hits_at_k │
# ╞═══════════╪════════╪════════════╪═════════════╡
# │ train     │ 0.8674 │     0.6401 │      0.9717 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ vali      │ 0.9949 │     0.5572 │      0.9739 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ test      │ 1.0048 │     0.5767 │      0.9622 │
# ╘═══════════╧════════╧════════════╧═════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  44
# Took 0.5315s
# ╒═══════════╤════════╤════════════╤═════════════╕
# │ quality   │   loss │   accuracy │   hits_at_k │
# ╞═══════════╪════════╪════════════╪═════════════╡
# │ train     │ 0.8643 │     0.6410 │      0.9719 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ vali      │ 0.9945 │     0.5572 │      0.9739 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ test      │ 1.0044 │     0.5752 │      0.9622 │
# ╘═══════════╧════════╧════════════╧═════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  45
# Took 0.4613s
# ╒═══════════╤════════╤════════════╤═════════════╕
# │ quality   │   loss │   accuracy │   hits_at_k │
# ╞═══════════╪════════╪════════════╪═════════════╡
# │ train     │ 0.8612 │     0.6421 │      0.9721 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ vali      │ 0.9943 │     0.5556 │      0.9739 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ test      │ 1.0040 │     0.5790 │      0.9622 │
# ╘═══════════╧════════╧════════════╧═════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  46
# Took 0.4876s
# ╒═══════════╤════════╤════════════╤═════════════╕
# │ quality   │   loss │   accuracy │   hits_at_k │
# ╞═══════════╪════════╪════════════╪═════════════╡
# │ train     │ 0.8583 │     0.6434 │      0.9736 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ vali      │ 0.9940 │     0.5556 │      0.9755 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ test      │ 1.0037 │     0.5790 │      0.9630 │
# ╘═══════════╧════════╧════════════╧═════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  47
# Took 0.5232s
# ╒═══════════╤════════╤════════════╤═════════════╕
# │ quality   │   loss │   accuracy │   hits_at_k │
# ╞═══════════╪════════╪════════════╪═════════════╡
# │ train     │ 0.8553 │     0.6445 │      0.9743 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ vali      │ 0.9935 │     0.5556 │      0.9755 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ test      │ 1.0034 │     0.5790 │      0.9630 │
# ╘═══════════╧════════╧════════════╧═════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  48
# Took 0.5500s
# ╒═══════════╤════════╤════════════╤═════════════╕
# │ quality   │   loss │   accuracy │   hits_at_k │
# ╞═══════════╪════════╪════════════╪═════════════╡
# │ train     │ 0.8524 │     0.6454 │      0.9749 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ vali      │ 0.9934 │     0.5556 │      0.9755 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ test      │ 1.0033 │     0.5806 │      0.9638 │
# ╘═══════════╧════════╧════════════╧═════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  49
# Took 0.5091s
# ╒═══════════╤════════╤════════════╤═════════════╕
# │ quality   │   loss │   accuracy │   hits_at_k │
# ╞═══════════╪════════╪════════════╪═════════════╡
# │ train     │ 0.8494 │     0.6469 │      0.9749 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ vali      │ 0.9930 │     0.5556 │      0.9755 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ test      │ 1.0030 │     0.5790 │      0.9638 │
# ╘═══════════╧════════╧════════════╧═════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  50
# Took 0.5451s
# ╒═══════════╤════════╤════════════╤═════════════╕
# │ quality   │   loss │   accuracy │   hits_at_k │
# ╞═══════════╪════════╪════════════╪═════════════╡
# │ train     │ 0.8465 │     0.6473 │      0.9749 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ vali      │ 0.9929 │     0.5572 │      0.9755 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ test      │ 1.0029 │     0.5790 │      0.9638 │
# ╘═══════════╧════════╧════════════╧═════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  51
# Took 0.5114s
# ╒═══════════╤════════╤════════════╤═════════════╕
# │ quality   │   loss │   accuracy │   hits_at_k │
# ╞═══════════╪════════╪════════════╪═════════════╡
# │ train     │ 0.8437 │     0.6493 │      0.9756 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ vali      │ 0.9928 │     0.5572 │      0.9755 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ test      │ 1.0027 │     0.5806 │      0.9638 │
# ╘═══════════╧════════╧════════════╧═════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  52
# Took 0.4539s
# ╒═══════════╤════════╤════════════╤═════════════╕
# │ quality   │   loss │   accuracy │   hits_at_k │
# ╞═══════════╪════════╪════════════╪═════════════╡
# │ train     │ 0.8408 │     0.6513 │      0.9758 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ vali      │ 0.9926 │     0.5523 │      0.9755 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ test      │ 1.0025 │     0.5806 │      0.9638 │
# ╘═══════════╧════════╧════════════╧═════════════╛
# Validation loss on combined improved, model saved
#
#
# Epoch  53
# Took 0.4286s
# ╒═══════════╤════════╤════════════╤═════════════╕
# │ quality   │   loss │   accuracy │   hits_at_k │
# ╞═══════════╪════════╪════════════╪═════════════╡
# │ train     │ 0.8380 │     0.6534 │      0.9762 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ vali      │ 0.9929 │     0.5507 │      0.9755 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ test      │ 1.0024 │     0.5783 │      0.9638 │
# ╘═══════════╧════════╧════════════╧═════════════╛
# Last improvement of loss on combined happened 1 epoch ago
#
#
# Epoch  54
# Took 0.4248s
# ╒═══════════╤════════╤════════════╤═════════════╕
# │ quality   │   loss │   accuracy │   hits_at_k │
# ╞═══════════╪════════╪════════════╪═════════════╡
# │ train     │ 0.8353 │     0.6558 │      0.9771 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ vali      │ 0.9930 │     0.5539 │      0.9755 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ test      │ 1.0024 │     0.5806 │      0.9638 │
# ╘═══════════╧════════╧════════════╧═════════════╛
# Last improvement of loss on combined happened 2 epochs ago
#
#
# Epoch  55
# Took 0.4645s
# ╒═══════════╤════════╤════════════╤═════════════╕
# │ quality   │   loss │   accuracy │   hits_at_k │
# ╞═══════════╪════════╪════════════╪═════════════╡
# │ train     │ 0.8325 │     0.6580 │      0.9773 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ vali      │ 0.9929 │     0.5556 │      0.9755 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ test      │ 1.0022 │     0.5806 │      0.9638 │
# ╘═══════════╧════════╧════════════╧═════════════╛
# Last improvement of loss on combined happened 3 epochs ago
#
#
# Epoch  56
# Took 0.4488s
# ╒═══════════╤════════╤════════════╤═════════════╕
# │ quality   │   loss │   accuracy │   hits_at_k │
# ╞═══════════╪════════╪════════════╪═════════════╡
# │ train     │ 0.8298 │     0.6578 │      0.9773 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ vali      │ 0.9928 │     0.5523 │      0.9755 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ test      │ 1.0022 │     0.5798 │      0.9638 │
# ╘═══════════╧════════╧════════════╧═════════════╛
# Last improvement of loss on combined happened 4 epochs ago
#
#
# Epoch  57
# Took 0.4437s
# ╒═══════════╤════════╤════════════╤═════════════╕
# │ quality   │   loss │   accuracy │   hits_at_k │
# ╞═══════════╪════════╪════════════╪═════════════╡
# │ train     │ 0.8271 │     0.6611 │      0.9780 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ vali      │ 0.9928 │     0.5523 │      0.9755 │
# ├───────────┼────────┼────────────┼─────────────┤
# │ test      │ 1.0021 │     0.5821 │      0.9638 │
# ╘═══════════╧════════╧════════════╧═════════════╛
# Last improvement of loss on combined happened 5 epochs ago
#
# EARLY STOPPING due to lack of validation improvement, it has been 5 epochs since last validation accuracy improvement
#
# Best validation model epoch: 52
# Best validation model loss on validation set combined: 0.992576022553288
# Best validation model loss on test set combined: 1.002537983237732
#
# Finished: hyperparameter_training_optimized_model
# Saved to: /valohai/outputs/hyperparameter_training_optimized_model

# %%
# generating learning curves from training
learning_curves([opt_stats], 'quality',
                model_names=['optmized_model'],
                output_directory='/valohai/outputs/',
                file_format='png')
